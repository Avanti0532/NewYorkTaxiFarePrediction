# %% [markdown]
# This program will perform clustering using minibatch K-means once new features are added. Run this program after Add_features_SecondStep.ipynb

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#read .feather file generated in Add_features_SecondStep.ipynb
import time as time
z = time.time()
train = pd.read_feather('/content/gdrive/My Drive/Big data/Data files/data_features.feather')
elapsed = time.time() - z
print(elapsed)
# Out:
# 47.08827066421509

# %%
import time as time
z = time.time()
test = pd.read_feather('/content/gdrive/My Drive/Big data/Data files/.feather')
elapsed = time.time() - z
print(elapsed)

# %%
train[['pickup_longitude', 'pickup_latitude', 'dropoff_latitude', 'dropoff_longitude', 'haversine_distance', 'fare_amount']] = train[['pickup_longitude', 'pickup_latitude', 'dropoff_latitude', 'dropoff_longitude', 'haversine_distance', 'fare_amount']].astype('float32')

# %%
train[['passenger_count', 'month', 'weekday', 'hour', 'year']] = train[['passenger_count', 'month', 'weekday', 'hour', 'year']].astype('int16')

# %%
train.dtypes
# Out:
# key                                object
# fare_amount                       float32
# pickup_datetime       datetime64[ns, UTC]
# pickup_longitude                  float32
# pickup_latitude                   float32
# dropoff_longitude                 float32
# dropoff_latitude                  float32
# passenger_count                     int16
# month                               int16
# weekday                             int16
# hour                                int16
# date                               object
# year                                int16
# haversine_distance                float32
# dtype: object

# %%
train.head(5)
# Out:
#                              key  fare_amount  ...  year  haversine_distance
# 0    2009-06-15 17:26:21.0000001          4.5  ...  2009            0.640668
# 1    2010-01-05 16:52:16.0000002         16.9  ...  2010            5.252153
# 2   2011-08-18 00:35:00.00000049          5.7  ...  2011            0.863655
# 3    2012-04-21 04:30:42.0000001          7.7  ...  2012            1.739877
# 4  2010-03-09 07:51:00.000000135          5.3  ...  2010            1.242569
#
# [5 rows x 14 columns]

# %%
train['fare_amount'].corr(train['haversine_distance'], method = 'spearman')
# Out:
# 0.8595939480813626

# %%
z = time.time()
sample_data = train.sample(frac = 0.6)
from sklearn.cluster import MiniBatchKMeans
cost = [] 
for i in range(9, 16): 
    KM_pickup = MiniBatchKMeans(n_clusters = i) 
    KM_pickup.fit(sample_data[['pickup_latitude', 'pickup_longitude']])
    cost.append(KM_pickup.inertia_)
elapsed = time.time() - z
print (elapsed)
# Out:
# 606.9039461612701

# %%
print(cost)
# Out:
# [31044961.935924705, 29788598.07215468, 30671789.64865398, 30599289.153786138, 30333700.827912755, 29007230.302776948, 32308486.532748986]

# %%
z = time.time()
from sklearn.cluster import MiniBatchKMeans
cost = [] 
for i in range(9, 16): 
    KM_dropoff = MiniBatchKMeans(n_clusters = i) 
    KM_dropoff.fit(sample_data[['dropoff_latitude', 'dropoff_longitude']])
    cost.append(KM_dropoff.inertia_)
elapsed = time.time() - z
print (elapsed)
# Out:
# 578.5001404285431

# %%
z = time.time()
from sklearn.cluster import MiniBatchKMeans
KM_pickup = MiniBatchKMeans(n_clusters = 10) 
KM_pickup_train = KM_pickup.fit(train[['pickup_latitude', 'pickup_longitude']])
elapsed = time.time() - z
print (elapsed)
# Out:
# 197.46772980690002

# %%
KM_pickup_test = KM_pickup.fit_predict(test[['pickup_latitude', 'pickup_longitude']])

# %%
train['pickup_cluster'] = KM_pickup_train.labels_
pickup_labels = KM_pickup_train.labels_

# %%
test['pickup_cluster'] = KM_pickup.fit_predict(test[['pickup_latitude', 'pickup_longitude']]).labels_

# %%
z = time.time()
from sklearn.cluster import MiniBatchKMeans
KM_dropoff = MiniBatchKMeans(n_clusters = 13)
KM_dropoff_train = KM_dropoff.fit(train[['dropoff_latitude', 'dropoff_longitude']])
elapsed = time.time() - z
print (elapsed)
# Out:
# 208.04515027999878

# %%
KM_pickup_test = KM_pickup.fit_predict(test[['dropoff_latitude', 'dropoff_longitude']])

# %%
train['dropoff_cluster'] = KM_dropoff.fit(train[['dropoff_latitude', 'dropoff_longitude']]).labels_
dropoff_labels = KM_dropoff_train.labels_

# %%
test['dropoff_cluster'] = KM_dropoff.fit_predict(test[['dropoff_latitude', 'dropoff_longitude']]).labels_

# %%
z = time.time()
plt.figure(figsize =(20,20))
ax = sns.scatterplot(x = 'pickup_longitude', y = 'pickup_latitude', hue = 'pickup_cluster', alpha = 0.2, data = data, palette = 'viridis', marker = 0, s = 20)
elapsed = time.time() - z
print (elapsed)

# %%
z = time.time()
plt.figure(figsize =(20,20))
ax = sns.scatterplot(x = 'dropoff_longitude', y = 'dropoff_latitude', hue = 'dropoff_cluster', alpha = 0.2, data = data, palette = 'viridis', marker = 0, s = 20)
elapsed = time.time() - z
print (elapsed)

# %%
#data.to_feather('data.feather')

# %%
pip install gmplot
# Out:
# ...
#      |████████████████████████████████| 122kB 2.8MB/s
# ...
#   Created wheel for gmplot: filename=gmplot-1.2.0-cp36-none-any.whl size=143765 sha256=abfbfd667f71544378125f34df0c41979ba019e0c3cf04e99736c405c9ff0fe0
#   Stored in directory: /root/.cache/pip/wheels/81/6a/76/4dd6a7cc310ba765894159ee84871e8cd55221d82ef14b81a1
# Successfully built gmplot
# ...

# %%
import gmplot

# %%
gmap1 = gmplot.GoogleMapPlotter(center_lat = 40.65, center_lng = -78.93, zoom = 13, apikey = 'AIzaSyBiRW_pqmdsbknUCx_LEMXiiKAT1IspwrE')

# %%
gmap1.scatter(pickup_coordinates[:,1], pickup_coordinates[:,0],color= '##0000ff',size = 200, marker = False )

# %%
gmap1.scatter(dropoff_coordinates[:,1], dropoff_coordinates[:,0], color ='#ff0000', size = 200, marker = False )

# %%
gmap1.draw('map1.html')
